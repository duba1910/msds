# %%
from IPython.display import Image
Image(filename="images/ppd_1.png")

# %%
Image(filename="images/ppd_2.png")

# %%
Image(filename="images/ppd_3.png")

# %%
Image(filename="images/ppd_4.png")

# %%
Image(filename="images/ppd_5.png")
