# %%
from IPython.display import Image
Image(filename="images/ddn_1.png")

# %%
Image(filename="images/ddn_2.png")

# %%
Image(filename="images/ddn_3.png")

# %%
Image(filename="images/ddn_4.png")

# %%
Image(filename="images/ddn_5.png")

# %%
Image(filename="images/ddn_6.png")

# %%
Image(filename="images/ddn_7.png")

# %%
Image(filename="images/ddn_8.png")

# %%
Image(filename="images/ddn_9.png")
