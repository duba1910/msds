# %%
from IPython.display import Image
Image(filename="images/tsht_1.png")

# %%
Image(filename="images/tsht_2.png")

# %%
Image(filename="images/tsht_3.png")
# 8 != 100 or 72 or 64
#

# %%
Image(filename="images/tsht_4.png")
# 11 != 1.2226 or 1.2222
# 12 != 0.2329 or 0.2336

# %%
Image(filename="images/tsht_5.png")

# %%
Image(filename="images/tsht_6.png")

# %%
Image(filename="images/tsht_7.png")

# %%
Image(filename="images/tsht_8.png")

# %%
Image(filename="images/tsht_9.png")

# %%
Image(filename="images/tsht_10.png")

# %%
Image(filename="images/tsht_11.png")
# 21 != 25.5324 or 25.5771 or 25.5225
# 
#

# %%
Image(filename="images/tsht_12.png")

# %%
Image(filename="images/tsht_13.png")
#23 != 1.6044 or 2.0595

# %%
Image(filename="images/tsht_14.png")

# %%
Image(filename="images/tsht_15.png")
# 27 != 1.6960 or 1.6959
# 28 != 10.5413

# %%
Image(filename="images/tsht_16.png")

# %%
Image(filename="images/tsht_17.png")
# 32 != 0.1698 or 0.1694 or .6630

# %%
Image(filename="images/tsht_18.png")

# %%
Image(filename="images/tsht_19.png")

# %%
Image(filename="images/tsht_20.png")
# 37 != .2501 or.2625

# %%
Image(filename="images/tsht_21.png")
