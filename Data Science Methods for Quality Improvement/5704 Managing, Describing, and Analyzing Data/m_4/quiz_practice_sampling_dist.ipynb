# %%
from IPython.display import Image
Image(filename="images/practice_1.png")

# %%
Image(filename="images/practice_2.png")

# %%
Image(filename="images/practice_3.png")

# %%
Image(filename="images/practice_4.png")

# %%
Image(filename="images/practice_5.png")

# %%
Image(filename="images/practice_6.png")

# %%
Image(filename="images/practice_7.png")

# %%
Image(filename="images/practice_8.png")
