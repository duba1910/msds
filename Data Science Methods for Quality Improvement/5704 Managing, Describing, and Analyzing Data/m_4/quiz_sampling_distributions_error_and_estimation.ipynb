# %%
from IPython.display import Image
Image(filename="images/sdee_1.png")

# %%
Image(filename="images/sdee_2.png")

# %%
Image(filename="images/sdee_3.png")
#add joint prob under dependent

# %%
Image(filename="images/sdee_4.png")

# %%
Image(filename="images/sdee_5.png")

# %%
Image(filename="images/sdee_6.png")

# %%
Image(filename="images/sdee_7.png")

# %%
Image(filename="images/sdee_8.png")
