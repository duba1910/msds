# %%
from IPython.display import Image
Image(filename="images/ddg_1.png")

# %%
Image(filename="images/ddg_2.png")

# %%
Image(filename="images/ddg_3.png")

# %%
Image(filename="images/ddg_4.png")

# %%
Image(filename="images/ddg_5.png")

# %%
Image(filename="images/ddg_6.png")

# %%
Image(filename="images/ddg_7.png")

# %%
Image(filename="images/ddg_8.png")
