# %%
from IPython.display import Image
Image(filename="images/npc_1.png")

# %%
from IPython.display import Image
Image(filename="images/npc_2.png")

# %%
from IPython.display import Image
Image(filename="images/npc_3.png")
