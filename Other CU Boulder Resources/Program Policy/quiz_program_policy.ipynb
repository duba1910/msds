# %%
from IPython.display import Image
Image(filename="images/p_p_1.png")

# %%
Image(filename="images/p_p_2.png")

# %%
Image(filename="images/p_p_3.png")

# %%
Image(filename="images/p_p_4.png")

# %%
Image(filename="images/p_p_5.png")

# %%
Image(filename="images/p_p_6.png")

# %%
Image(filename="images/p_p_7.png")

# %%
Image(filename="images/p_p_8.png")

# %%
Image(filename="images/p_p_9.png")

# %%
Image(filename="images/p_p_10.png")

# %%
Image(filename="images/p_p_12.png")

# %%
Image(filename="images/p_p_13.png")

# %%
Image(filename="images/p_p_14.png")

# %%
Image(filename="images/p_p_15.png")
# should be 14 days

# %%
Image(filename="images/p_p_16.png")

# %%
Image(filename="images/p_p_17.png")
