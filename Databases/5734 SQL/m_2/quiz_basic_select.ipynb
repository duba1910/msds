# %%
from IPython.display import Image
Image(filename="images/bs_1.png")

# %%
Image(filename="images/bs_2.png")

# %%
Image(filename="images/bs_3.png")

# %%
Image(filename="images/bs_4.png")

# %%
Image(filename="images/bs_5.png")

# %%
Image(filename="images/bs_6.png")

# %%
Image(filename="images/bs_7.png")

# %% [markdown]
# ---
