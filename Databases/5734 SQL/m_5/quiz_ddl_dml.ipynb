# %%
from IPython.display import Image
Image(filename="images/ddl_dml_1.png")

# %%
from IPython.display import Image
Image(filename="images/ddl_dml_2.png")

# %%
from IPython.display import Image
Image(filename="images/ddl_dml_3.png")
