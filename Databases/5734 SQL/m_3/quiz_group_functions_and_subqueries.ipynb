# %%
from IPython.display import Image
Image(filename="images/g_s_1.png")

# %%
from IPython.display import Image
Image(filename="images/g_s_2.png")

# %%
from IPython.display import Image
Image(filename="images/g_s_3.png")

# %%
from IPython.display import Image
Image(filename="images/g_s_4.png")

# %%
from IPython.display import Image
Image(filename="images/g_s_5.png")

# %% [markdown]
# ---
