# %%
from IPython.display import Image
Image(filename="images/fd1.png")

# %% [markdown]
# Possible FDs are: (let’s assume there will be duplicate names)
#
# FD1: ID → Name, Major, Quiz2, Quiz2, Quiz3, Quiz4, Total, Grade
#
# FD2: Quiz1, Quiz2, Quiz3, Quiz4 → Total
#
# FD3: Total → Grade

# %%
Image(filename="images/fd2.png")

# %% [markdown]
# Relation 2:
# SKU → Name
#
# SKU, VendorID, Date → Price, Quantity, Location, Description
#
# (It is possible for the same SKU, Vendor, with the same price, there are multiple dates, so we cannot have price in the determinators).
