# %%
from IPython.display import Image
Image(filename="images/cv_n_1.png")

# %%
Image(filename="images/cv_n_2.png")

# %%
Image(filename="images/cv_n_3.png")

# %%
Image(filename="images/cv_n_4.png")

# %%
Image(filename="images/cv_n_5.png")

# %%
Image(filename="images/cv_n_6.png")

# %%
Image(filename="images/cv_n_7.png")
