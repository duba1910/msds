# %%
from IPython.display import Image
Image(filename="images/t_1.png")

# %%
Image(filename="images/t_2.png")

# %%
Image(filename="images/t_3.png")

# %%
Image(filename="images/t_4.png")

# %%
Image(filename="images/t_5.png")
