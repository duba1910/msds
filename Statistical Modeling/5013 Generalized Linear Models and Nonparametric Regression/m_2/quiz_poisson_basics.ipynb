# %%
from IPython.display import Image
Image(filename="images/basics_1.png")

# %%
Image(filename="images/basics_2.png")

# %%
Image(filename="images/basics_3.png")

# %%
Image(filename="images/basics_4.png")

# %%
Image(filename="images/basics_5.png")
