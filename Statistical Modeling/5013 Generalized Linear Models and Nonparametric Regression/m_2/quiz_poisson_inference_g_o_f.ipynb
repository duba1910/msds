# %%
from IPython.display import Image
Image(filename="images/i_g_o_f_1.png")

# %%
Image(filename="images/i_g_o_f_2.png")

# %%
Image(filename="images/i_g_o_f_3.png")

# %%
Image(filename="images/i_g_o_f_4.png")
