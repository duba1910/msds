# %%
from IPython.display import Image
Image(filename="images/n_r_t_1.png")

# %%
Image(filename="images/n_r_t_2.png")

# %%
Image(filename="images/n_r_t_3.png")

# %%
Image(filename="images/n_r_t_4.png")

# %%
Image(filename="images/n_r_t_5.png")
