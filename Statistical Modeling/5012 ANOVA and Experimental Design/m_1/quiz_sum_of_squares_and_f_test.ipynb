# %%
from IPython.display import Image
Image(filename="images/sos_f_1.png")

# %%
Image(filename="images/sos_f_2.png")

# %%
Image(filename="images/sos_f_3.png")

# %%
Image(filename="images/sos_f_4.png")
