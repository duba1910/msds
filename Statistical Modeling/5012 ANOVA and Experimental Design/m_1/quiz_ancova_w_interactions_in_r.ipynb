# %%
from IPython.display import Image
Image(filename="images/ancova_w_int_r_1.png")

# %%
Image(filename="images/ancova_w_int_r_2.png")

# %%
Image(filename="images/ancova_w_int_r_3.png")

# %%
Image(filename="images/ancova_w_int_r_4.png")
