# %%
from IPython.display import Image
Image(filename="images/int_def_viz_1.png")

# %%
Image(filename="images/int_def_viz_2.png")

# %%
Image(filename="images/int_def_viz_3.png")

# %%
Image(filename="images/int_def_viz_4.png")
