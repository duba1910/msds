# %%
from IPython.display import Image
Image(filename="images/3_1.png")

# %%
Image(filename="images/3_2.png")

# %%
Image(filename="images/3_3.png")

# %%
Image(filename="images/3_4.png")

# %%
Image(filename="images/3_5.png")

# %%
Image(filename="images/3_6.png")

# %%
Image(filename="images/3_7.png")
