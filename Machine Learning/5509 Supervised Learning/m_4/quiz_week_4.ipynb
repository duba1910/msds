# %%
from IPython.display import Image
Image(filename="images/4_1.png")

# %%
Image(filename="images/4_2.png")

# %%
Image(filename="images/4_3.png")

# %%
Image(filename="images/4_4.png")

# %%
Image(filename="images/4_5.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Image(filename="images/4_5.png")
#
# File c:\Users\dusti\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File c:\Users\dusti\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# ...

# %%
Image(filename="images/4_6.png")

# %%
Image(filename="images/4_7.png")
