# %%
from IPython.display import Image
Image(filename="images/1_1.png")

# %%
Image(filename="images/1_2.png")

# %%
Image(filename="images/1_3.png")

# %%
Image(filename="images/1_4.png")

# %%
Image(filename="images/1_5.png")

# %%
Image(filename="images/1_6.png")

# %%
Image(filename="images/1_7.png")

# %%
Image(filename="images/1_8.png")

# %%
Image(filename="images/1_9.png")

# %%
Image(filename="images/1_10.png")
