# %%
from IPython.display import Image
Image(filename="images/2_1.png")

# %%
Image(filename="images/2_2.png")

# %%
Image(filename="images/2_3.png")

# %%
Image(filename="images/2_4.png")

# %%
Image(filename="images/2_5.png")

# %%
Image(filename="images/2_6.png")

# %%
Image(filename="images/2_7.png")

# %%
Image(filename="images/2_8.png")
