# %%
from IPython.display import Image
Image(filename="images/6_1.png")

# %%
Image(filename="images/6_2.png")

# %%
Image(filename="images/6_3.png")

# %%
Image(filename="images/6_4.png")

# %%
Image(filename="images/6_5.png")
